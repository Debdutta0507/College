# %% [markdown]
# <a href="https://colab.research.google.com/github/Debdutta0507/College/blob/master/Module8/FMML20210377_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-16 19:00:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   166MB/s    in 0.4s
#
# 2022-06-16 19:00:55 (166 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 9972   1511.08967v1  Reinforcement learning (RL) is a general and w...    cs
# 38943   1403.3022v1  Legendre orthogonal moments have been widely u...    cs
# 821    1702.06054v1  Reinforcement Learning algorithms can learn co...    cs
# 19476   1107.2090v1  IT Service Management deals with managing a br...    cs
# 30612  1712.07732v1  Visual recognition under adverse conditions is...    cs
# ...             ...                                                ...   ...
# 21809  1604.07463v1  We consider a firm that sells products over $T...  stat
# 33687  1509.09199v1  With the increasing complexity of computing sy...    cs
# 39122   1312.2061v1  In this paper, region based and location based...    cs
# 19741   1205.2659v1  We study a subclass of POMDPs, called Determin...    cs
# 14227  1505.02213v3  Given a high-dimensional data set we often wis...  stat
#
#                                                    title  year  \
# 9972   Robotic Search & Rescue via Online Multi-task ...  2015
# 38943  Efficient Legendre moment computation for grey...  2014
# 821    Learning to Repeat: Fine Grained Action Repeti...  2017
# 19476  Semantic-ontological combination of Business R...  2011
# 30612  Enhance Visual Recognition under Adverse Condi...  2017
# ...                                                  ...   ...
# 21809             Dynamic Pricing with Demand Covariates  2016
# 33687    Fault Tolerance in Distributed Neural Computing  2015
# 39122  Region and Location Based Indexing and Retriev...  2013
# 19741                     Deterministic POMDPs Revisited  2012
# 14227      Measuring dependence powerfully and equitably  2015
#
#                                                 keywords
# 9972   [reinforcement, particular, versatile, prohibi...
# 38943  [orthogonal, computation, expensive, reduction...
# 821    [reinforcement, algorithms, behavioral, sequen...
# 19476  [management, environments, connection, interes...
# 30612  [recognition, conditions, important, challengi...
# ...                                                  ...
# 21809  [sequentially, underlying, simultaneously, heu...
# 33687  [increasing, complexity, computing, reliabilit...
# 39122  [retrieval, implemented, retrieval, extracting...
# 19741  [deterministic, characterized, deterministic, ...
# 14227  [dimensional, strongest, relationships, depend...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 9972     [reinforcement, particular, versatile, prohibi...
# 38943    [orthogonal, computation, expensive, reduction...
# 821      [reinforcement, algorithms, behavioral, sequen...
# 19476    [management, environments, connection, interes...
# 30612    [recognition, conditions, important, challengi...
#                                ...
# 4334     [understanding, important, applications, under...
# 30386    [framework, detection, contribution, innovativ...
# 19723    [representing, semantics, computing, structure...
# 5406     [introduce, embarrassingly, parameter, algorit...
# 38361    [combination, traditional, classification, mem...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8760 words.
# Out of those 4516 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0aad382b-5658-406e-ad81-fe9ecdf52c6d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0aad382b-5658-406e-ad81-fe9ecdf52c6d")) {                    Plotly.newPlot(                        "0aad382b-5658-406e-ad81-fe9ecdf52c6d",                        [{"x":["implemented","algorithm","conditions","different","evaluated","environment","efficiently","reinforcement","versatile","consecutive","prohibitively","accelerate","efficient","knowledge","particular","expensive","performance","implementations","empirical","calculation","dimensional","computation","combination","recursive","reduction","complexity","nevertheless","expressed","relationship","multiplication","recurrence","quantities","algorithms","computational","orthogonal","polynomials","computing","traditionally","sequential","gradients","framework","advantage","interactions","repeating","improvements","improving","optimization","behavioral","repetition","asynchronous","decisions","empirically","demonstrate","maintains","interacts","deterministic","abstractions","regarding","presented","application","seamlessly","expressions","integration","executable","relationships","connection","interests","management","environments","semantics","transparency","challenges","infrastructure","ontological","applications","furthermore","processes","ontologies","expressing","discussed","inheritance","integrated","generalizes","distortions","existence","extensively","techniques","augmentation","recognition","challenging","practical","restoration","exploited","aggressive","unsupervised","significant","important","explainability","comprehensively","respectively","visualization","conventional","acquisition","transmission","ubiquitous","benchmarks","optimized","collection","learnings","benchmark","inventory","baselines","components","compromising","categories","signature","architecture","inference","relevance","optimizations","distributed","discussions","availability","currently","requiring","supervised","predicted","precision","constraints","guarantees","experiments","resulting","functions","appropriate","alternating","monotonicity","embeddings","implement","ensembles","monotonic","stochastic","tensorflow","regression","projections","specified","classification","optimizer","successfully","adaptable","robustness","segmentation","essential","detection","automatic","solutions","variation","histogram","illumination","quantitative","ethnicity","effectiveness","qualitative","comparison","distributions","generative","measurable","effective","distribution","achieving","improvement","implementation","parameterized","hamiltonian","generalizing","exploration","directions","operation","experimentally","parameters","architectures","structured","approaches","combining","themselves","convolutional","invariance","strategies","properties","generalized","operations","including","comparisons","significantly","stability","applicable","selective","operators","dependent","outperforms","partially"],"y":[112,799,120,707,136,126,141,111,9,20,6,13,419,346,285,68,903,41,154,15,164,140,143,26,108,213,20,38,71,10,6,20,569,281,16,9,109,18,88,32,571,91,70,5,118,103,321,17,2,12,42,68,535,17,3,41,10,36,191,269,10,33,41,3,70,46,11,44,71,109,3,116,21,10,409,164,101,28,12,55,6,66,37,9,35,34,365,24,396,259,129,17,39,6,160,227,347,2,4,80,32,112,37,12,22,102,54,76,1,208,8,62,95,9,84,17,259,209,34,9,104,10,26,53,51,170,36,80,129,60,609,170,223,80,25,4,89,76,9,18,134,5,114,19,44,504,5,90,9,97,174,70,341,183,144,61,16,39,71,2,212,56,126,110,125,1,225,222,99,129,136,15,2,13,61,31,47,54,247,145,100,427,96,19,360,20,97,203,76,64,225,22,246,41,57,16,51,73,254,40],"type":"bar"},{"x":["implemented","algorithm","conditions","different","evaluated","environm ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4516,), (4516, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Material</span> <span style=''>Editing</span> <span style=''>Using</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>Physically</span> <span style=''>Based</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>Rendering</span> <span style=''>Network</span> <br/><br/><span style=''>The</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>edit</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>materials</span> <span style=''>of</span> <span style=''>objects</span> <span style=''>in</span> <span style=''>images</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>by</span> <span style=''>many</span> <span style=''>content</span> <span style=''>creators</span> <span style=''>However</span> <span style=''>this</span> <span style=''>is</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extremely</span> <span style='background-color:rgba(0, 255, 0, 0.43093922651933697);'>challenging</span> <span style=''>task</span> <span style=''>as</span> <span style=''>it</span> <span style=''>requires</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>disentangle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style=''>physical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>an</span> <span style=''>image</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.5370919881305638);'>architecture</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>replicates</span> <span style=''>the</span> <span style=''>forward</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>formation</span> <span style=''>process</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accomplish</span> <span style=''>this</span> <span style=''>task</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>given</span> <span style=''>a</span> <span style=''>single</span> <span style=''>image</span> <span style=''>the</span> <span style=''>network</span> <span style=''>first</span> <span style=''>predicts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>ie</span> <span style=''>shape</span> <span style='background-color:rgba(0, 255, 0, 0.9500000000000001);'>illumination</span> <span style=''>and</span> <span style=''>material</span> <span style=''>which</span> <span style=''>are</span> <span style=''>then</span> <span style=''>provided</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>rendering</span> <span style=''>layer</span> <span style=''>This</span> <span style=''>layer</span> <span style=''>performs</span> <span style=''>in</span> <span style=''>network</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6551724137931034);'>synthesis</span> <span style=''>thereby</span> <span style=''>enabling</span> <span style=''>the</span> <span style=''>network</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>understand</span> <span style=''>the</span> <span style=''>physics</span> <span style=''>behind</span> <span style=''>the</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5789473684210527);'>formation</span> <span style=''>process</span> <span style=''>The</span> <span style=''>proposed< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Confident</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>for</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>at</span> <span style=''>Uber</span> <br/><br/><span style=''>Reliable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>is</span> <span style=''>critical</span> <span style=''>in</span> <span style=''>many</span> <span style=''>fields</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>physics</span> <span style=''>biology</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>manufacturing</span> <span style=''>At</span> <span style=''>Uber</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>is</span> <span style=''>used</span> <span style=''>for</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>of</span> <span style=''>number</span> <span style=''>of</span> <span style=''>trips</span> <span style=''>during</span> <span style=''>special</span> <span style=''>events</span> <span style=''>driver</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incentive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>real</span> <span style=''>time</span> <span style=''>anomaly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>across</span> <span style=''>millions</span> <span style=''>of</span> <span style=''>metrics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classical</span> <span style=''>time</span> <span style=''>series</span> <span style=''>models</span> <span style=''>are</span> <span style=''>often</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjunction</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>However</span> <span style=''>such</span> <span style=''>models</span> <span style=''>are</span> <span style=''>hard</span> <span style=''>to</span> <span style=''>tune</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>add</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exogenous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resurgence</span> <span style=''>of</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Memory</span> <span style=''>networks</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>Bayesian</span> <span style=''>deep</span> <span style=''>model</span> <span style=''>that</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Duality</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>subgradient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>gradient</span> <span style=''>methods</span> <br/><br/><span style=''>Given</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>its</span> <span style=''>dual</span> <span style=''>there</span> <span style=''>are</span> <span style=''>many</span> <span style=''>possible</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>between</span> <span style=''>mirror</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>This</span> <span style=''>is</span> <span style=''>done</span> <span style=''>through</span> <span style=''>convex</span> <span style=''>duality</span> <span style=''>and</span> <span style=''>implies</span> <span style=''>notably</span> <span style=''>that</span> <span style=''>for</span> <span style=''>certain</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>non</span> <span style=''>smooth</span> <span style=''>losses</span> <span style=''>or</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.5223880597014925);'>regularized</span> <span style=''>by</span> <span style=''>non</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizers</span> <span style=''>the</span> <span style=''>primal</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>subgradient</span> <span style=''>method</span> <span style=''>and</span> <span style=''>the</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>are</span> <span style=''>formally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>The</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>form</span> <span style=''>of</span> <span style=''>line</span> <span style=''>search</span> <span style=''>for</span> <span style=''>mirror</span> <span style=''>descent</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3548387096774194);'>guarantees</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>for</span> <span style=''>primal</span> <span style=''>dual</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>certificates</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>CoRE</span> <span style=''>Kernels</span> <br/><br/><span style=''>The</span> <span style=''>term</span> <span style=''>CoRE</span> <span style=''>kernel</span> <span style=''>stands</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resemblance</span> <span style=''>kernel</span> <span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>(eg</span> <span style=''>vision)</span> <span style=''>the</span> <span style=''>data</span> <span style=''>are</span> <span style=''>often</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>sparse</span> <span style=''>and</span> <span style=''>non</span> <span style=''>binary</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>types</span> <span style=''>of</span> <span style=''>(nonlinear)</span> <span style=''>CoRE</span> <span style=''>kernels</span> <span style=''>for</span> <span style=''>non</span> <span style=''>binary</span> <span style=''>sparse</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>new</span> <span style=''>kernels</span> <span style=''>through</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiment</span> <span style=''>CoRE</span> <span style=''>kernels</span> <span style=''>are</span> <span style=''>simple</span> <span style=''>with</span> <span style=''>no</span> <span style=''>tuning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>However</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>kernel</span> <span style=''>SVM</span> <span style=''>can</span> <span style=''>be</span> <span style=''>(very)</span> <span style=''>costly</span> <span style=''>in</span> <span style=''>time</span> <span style=''>and</span> <span style=''>memory</span> <span style=''>and</span> <span style=''>may</span> <span style=''>not</span> <span style=''>be</span> <span style=''>suitable</span> <span style=''>for</span> <span style=''>truly</span> <span style=''>large</span> <span style=''>scale</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>industrial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>(eg</span> <span style=''>search)</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>make</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>CoRE</span> <span style=''>kernels</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>basic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>hashing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>kernels</span> <span style=''>into</span> <span style=''>linear</span> <span style=''>kernels</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05019579921680313)
# 	segmentation (0.0619437522249911)
# 	architecture (0.09220363118547525)
# 	experimental (0.13670345318618726)
# 	representation (0.13777144891420434)
# 	different (0.25169099323602706)
# 	detection (0.12139551441794233)
# 	information (0.25453898184407264)
# 	convolutional (0.12815948736205054)
# 	recognition (0.1409754360982556)
#
# Some Statistics words are:
# 	stochastic (0.13711702661978906)
# 	variables (0.13309894525364138)
# 	theoretical (0.14917127071823205)
# 	distribution (0.18031140130587645)
# 	statistical (0.16423907584128578)
# 	estimation (0.1772978402812657)
# 	algorithm (0.39678553490708185)
# 	inference (0.19889502762430938)
# 	dimensional (0.18935208437970869)
# 	regression (0.1757910597689603)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="86b23a81-57f4-4db3-ba05-40d3f1afd79b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86b23a81-57f4-4db3-ba05-40d3f1afd79b")) {                    Plotly.newPlot(                        "86b23a81-57f4-4db3-ba05-40d3f1afd79b",                        [{"x":["implemented","algorithm","conditions","different","evaluated","environment","efficiently","reinforcement","versatile","consecutive","prohibitively","accelerate","efficient","knowledge","particular","expensive","performance","implementations","empirical","calculation","dimensional","computation","combination","recursive","reduction","complexity","nevertheless","expressed","relationship","multiplication","recurrence","quantities","algorithms","computational","orthogonal","polynomials","computing","traditionally","sequential","gradients","framework","advantage","interactions","repeating","improvements","improving","optimization","behavioral","repetition","asynchronous","decisions","empirically","demonstrate","maintains","interacts","deterministic","abstractions","regarding","presented","application","seamlessly","expressions","integration","executable","relationships","connection","interests","management","environments","semantics","transparency","challenges","infrastructure","ontological","applications","furthermore","processes","ontologies","expressing","discussed","inheritance","integrated","generalizes","distortions","existence","extensively","techniques","augmentation","recognition","challenging","practical","restoration","exploited","aggressive","unsupervised","significant","important","explainability","comprehensively","respectively","visualization","conventional","acquisition","transmission","ubiquitous","benchmarks","optimized","collection","learnings","benchmark","inventory","baselines","components","compromising","categories","signature","architecture","inference","relevance","optimizations","distributed","discussions","availability","currently","requiring","supervised","predicted","precision","constraints","guarantees","experiments","resulting","functions","appropriate","alternating","monotonicity","embeddings","implement","ensembles","monotonic","stochastic","tensorflow","regression","projections","specified","classification","optimizer","successfully","adaptable","robustness","segmentation","essential","detection","automatic","solutions","variation","histogram","illumination","quantitative","ethnicity","effectiveness","qualitative","comparison","distributions","generative","measurable","effective","distribution","achieving","improvement","implementation","parameterized","hamiltonian","generalizing","exploration","directions","operation","experimentally","parameters","architectures","structured","approaches","combining","themselves","convolutional","invariance","strategies","properties","generalized","operations","including","comparisons","significantly","stability","applicable","selective","operators","dependent","outperforms","partially","crossover","confidence","parameter","researchers","interactive","represented","traveling","convenient","investigate","represent","benchmarking","experimental","selection","simulating","factorial","composite","streaming","motivated","communication","centralized","sufficient","autonomous","accelerated","approximation","numerical","averaging","collaborative","convergence","communications","consensus","perturbed","subgradient","contributions","approximate","remarkable","inexpensive","exponential","sophisticated","sufficiently","objectives","completely","designing","introduce","prohibitive","forecasters","computationally","abstention","specialist","reasonable","straightforward","addressing","aggregation","flexibility","increasingly","predicti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	integrality
# 	certificate
# 	negativity
# 	infectious
# 	looseness
# 	subdomains
# 	diagonalization
# 	eigenstructures
# 	converged
# 	normalised
# 	multiplier
# 	heteroskedastic
# 	particulars
# 	marginally
# 	refitting
# 	preselected
# 	logarithmically
# 	resurgence
# 	generalises
# 	psychiatric
# Some words which never appear in Statistics papers:
# 	abstractions
# 	ontological
# 	inheritance
# 	comprehensively
# 	ethnicity
# 	crossover
# 	traveling
# 	directionality
# 	reachability
# 	reachable
# 	forwarding
# 	abstracting
# 	physiology
# 	informatics
# 	stagewise
# 	binarization
# 	labelling
# 	affordable
# 	reconsider
# 	repairing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0669201987364294e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
